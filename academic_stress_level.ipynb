# %%
import pandas as pd             
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('datasets/academic_Stress_level.csv')
data.head()
# Out:
#              Timestamp Your Academic Stage  Peer pressure  \
# 0  24/07/2025 22:05:39       undergraduate              4
# 1  24/07/2025 22:05:52       undergraduate              3
# 2  24/07/2025 22:06:39       undergraduate              1
# 3  24/07/2025 22:06:45       undergraduate              3
# 4  24/07/2025 22:08:06       undergraduate              3
#
#    Academic pressure from your home Study Environment  \
# 0                                 5             Noisy
# 1                                 4          Peaceful
# 2                                 1          Peaceful
# 3                                 2          Peaceful
# 4                                 3          Peaceful
#
#           What coping strategy you use as a student?  \
# 0  Analyze the situation and handle it with intel...
# 1  Analyze the situation and handle it with intel...
# 2                   Social support (friends, family)
# 3  Analyze the situation and handle it with intel...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 9 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Timestamp                                                            140 non-null    object
#  1   Your Academic Stage                                                  140 non-null    object
#  2   Peer pressure                                                        140 non-null    int64
#  3   Academic pressure from your home                                     140 non-null    int64
#  4   Study Environment                                                    139 non-null    object
#  5   What coping strategy you use as a student?                           140 non-null    object
#  6   Do you have any bad habits like smoking, drinking on a daily basis?  140 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp                                                              0
# Your Academic Stage                                                    0
# Peer pressure                                                          0
# Academic pressure from your home                                       0
# Study Environment                                                      1
# What coping strategy you use as a student?                             0
# Do you have any bad habits like smoking, drinking on a daily basis?    0
# What would you rate the academic  competition in your student life     0
# Rate your academic stress index                                        0
# dtype: int64

# %%
data['Your Academic Stage'].value_counts()
# Out:
# Your Academic Stage
# undergraduate    100
# high school       29
# post-graduate     11
# Name: count, dtype: int64

# %%
data['Study Environment'].value_counts()
# Out:
# Study Environment
# Peaceful     69
# disrupted    38
# Noisy        32
# Name: count, dtype: int64

# %%
data['What coping strategy you use as a student?'].value_counts()
# Out:
# What coping strategy you use as a student?
# Analyze the situation and handle it with intellect    87
# Emotional breakdown (crying a lot)                    32
# Social support (friends, family)                      21
# Name: count, dtype: int64

# %%
data['Do you have any bad habits like smoking, drinking on a daily basis?'].value_counts()
# Out:
# Do you have any bad habits like smoking, drinking on a daily basis?
# No                   123
# Yes                   10
# prefer not to say      7
# Name: count, dtype: int64

# %%
data = data.drop(columns='Timestamp')
data.head()
# Out:
#   Your Academic Stage  Peer pressure  Academic pressure from your home  \
# 0       undergraduate              4                                 5
# 1       undergraduate              3                                 4
# 2       undergraduate              1                                 1
# 3       undergraduate              3                                 2
# 4       undergraduate              3                                 3
#
#   Study Environment         What coping strategy you use as a student?  \
# 0             Noisy  Analyze the situation and handle it with intel...
# 1          Peaceful  Analyze the situation and handle it with intel...
# 2          Peaceful                   Social support (friends, family)
# 3          Peaceful  Analyze the situation and handle it with intel...
# 4          Peaceful  Analyze the situation and handle it with intel...
#
#   Do you have any bad habits like smoking, drinking on a daily basis?  \
# ...

# %%
data.hist(bins=15, figsize=(15,10))
plt.show()

# %%
data.columns
# Out:
# Index(['Your Academic Stage', 'Peer pressure',
#        'Academic pressure from your home', 'Study Environment',
#        'What coping strategy you use as a student?',
#        'Do you have any bad habits like smoking, drinking on a daily basis?',
#        'What would you rate the academic  competition in your student life',
#        'Rate your academic stress index '],
#       dtype='object')

# %%
df = pd.DataFrame(data)
data_encoded = pd.get_dummies(df[['Study Environment', 'Your Academic Stage', 'What coping strategy you use as a student?', 'Do you have any bad habits like smoking, drinking on a daily basis?']], dtype=int)

data_encoded
# Out:
#      Study Environment_Noisy  Study Environment_Peaceful  \
# 0                          1                           0
# 1                          0                           1
# 2                          0                           1
# 3                          0                           1
# 4                          0                           1
# ..                       ...                         ...
# 135                        0                           1
# 136                        0                           0
# 137                        0                           1
# 138                        0                           0
# 139                        0                           1
#
#      Study Environment_disrupted  Your Academic Stage_high school  \
# 0                              0                                0
# 1                              0                                0
# 2                              0                                0
# ...

# %%
data_encoded['Rate your academic stress index '] = df['Rate your academic stress index ']

# %%
y = data_encoded['Rate your academic stress index ']
x = data_encoded.drop('Rate your academic stress index ', axis=1)

# %%
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(x_treino, y_treino)

score = model.score(x_teste, y_teste)
score
# Out:
# 0.2857142857142857

# %%
y_teste[1:5]
# Out:
# 57    3
# 15    4
# 70    4
# 10    5
# Name: Rate your academic stress index , dtype: int64

# %%
x_teste[1:5]
# Out:
#     Study Environment_Noisy  Study Environment_Peaceful  \
# 57                        1                           0
# 15                        1                           0
# 70                        0                           0
# 10                        0                           0
#
#     Study Environment_disrupted  Your Academic Stage_high school  \
# 57                            0                                0
# 15                            0                                0
# 70                            1                                0
# 10                            1                                0
#
#     Your Academic Stage_post-graduate  Your Academic Stage_undergraduate  \
# 57                                  0                                  1
# 15                                  0                                  1
# 70                                  0                                  1
# ...

# %%
previsao = model.predict(x_teste[1:5])
previsao
# Out:
# array([4, 4, 4, 4])
